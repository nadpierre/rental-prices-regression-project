# %% [markdown]
# # Canadian Rental Prices Feature Engineering and Data Preprocessing

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# This notebook prepares the data for a regression model that will predict the price of a rental based on multiple factors.
#
# We're going to work with the data that's been explored and cleaned in [this notebook](EDA.ipynb). The dataset contains rental prices data associated with multiple factors, like the location, type of rental, number of rooms, etc.
#
# The model selection to predict the price will be made in [this notebook](Regression.ipynb).

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# Load the data
df = pd.read_pickle('../Data/cleaned_data.pkl')
df.shape
# Out:
# (19045, 18)

# %%
df.sample(5)
# Out:
#        rentfaster_id      city  province  \
# 13195         566190    Ottawa   Ontario
# 656           477774   Calgary   Alberta
# 9872          568528  Winnipeg  Manitoba
# 8605          143797   Calgary   Alberta
# 16700         527987  Montréal    Quebec
#
#                                           address   latitude   longitude  \
# 13195  1350 Hemlock Road, Ottawa, Ontario K1K 5C2  45.452820  -75.632910
# 656                             912 6th Avenue SW  51.048157 -114.081637
# 9872                            384 Arnold Avenue  49.864198  -97.139262
# 8605                             901 10 Avenue SW  51.043560 -114.081911
# 16700                       360 President Kennedy  45.507216  -73.569636
#
#       lease_term       type   price  beds  baths  sq_feet  \
# 13195  Long Term  Apartment  1990.0     1    1.0    730.0
# 656    Long Term  Apartment  1715.0     1    1.0    530.0
# 9872   Long Term     Duplex  2200.0     3    2.5   2200.0
# 8605   Long Term  Apartment  1850.0     1    1.0    570.0
# 16700  Long Term  Apartment  1900.0     0    1.0    457.0
#
#                                                     link   furnishing  \
# 13195  /on/ottawa/rentals/apartment/1-bedroom/carson-...  Unfurnished
# 656    /ab/calgary/rentals/apartment/1-bedroom/downto...  Unfurnished
# 9872   /mb/winnipeg/rentals/duplex/3-bedrooms/lord-ro...  Unfurnished
# 8605   /ab/calgary/rentals/apartment/1-bedroom/beltli...  Unfurnished
# 16700  /qc/montreal/rentals/apartment/1-bedroom/pet-f...  Unfurnished
#
#       availability_date      smoking   cats   dogs
# 13195         Immediate  Non-Smoking   True   True
# 656           Immediate  Non-Smoking   True   True
# 9872          Immediate  Non-Smoking  False  False
# 8605          Immediate  Non-Smoking  False  False
# 16700         Immediate  Non-Smoking   True   True

# %% [markdown]
# ## 2. Simplify model by removing some columns

# %% [markdown]
# **rentfaster_id**: An ID column is not correlated in any way with the price.
#
# **province, address, latitude & longitude**: Location is an important factor in the price. However, having a model with all provinces and exact locations would overly complexify the model. Having the city should be enough to account location in our model.
#
# **link**: The link has no correlation with the price.
#
# **availability_date**: I don't think the availability date has anything to do with the price.

# %%
df.drop(columns=['rentfaster_id', 'province', 'address', 'latitude', 'longitude', 'link', 'availability_date'], axis=1, inplace=True)
df.sample(5)
# Out:
#           city lease_term        type   price  beds  baths  sq_feet  \
# 2062   Calgary  Long Term  Main Floor  2285.0     3    2.5   1485.0
# 8471   Nanaimo  Long Term   Apartment  2965.0     0    1.0   1348.0
# 5866  Edmonton  Long Term       House  2595.0     3    2.5   1752.0
# 5124  Edmonton  Long Term   Apartment  1434.0     2    1.0    880.0
# 5421  Edmonton  Long Term  Condo Unit  2250.0     2    2.0    795.0
#
#        furnishing      smoking   cats   dogs
# 2062  Unfurnished  Non-Smoking  False  False
# 8471  Unfurnished  Non-Smoking  False  False
# 5866  Unfurnished  Non-Smoking  False  False
# 5124  Unfurnished      Unknown   True   True
# 5421    Furnished  Non-Smoking  False  False

# %% [markdown]
# ## 3. Encode categorical columns

# %% [markdown]
# ### 3.1 Boolean

# %%
# Create dummy variables
df = df.assign(
    dogs=np.where(df['dogs'] == True, 1, 0),
    cats=np.where(df['cats'] == True, 1, 0),
)
df.sample(5)
# Out:
#                city lease_term       type   price  beds  baths      sq_feet  \
# 5042       Edmonton  Long Term  Apartment  1420.0     0    1.0     0.000000
# 17896      Montréal  Long Term  Apartment  1395.0     1    1.0  1371.060606
# 3616        Calgary  Long Term  Apartment  2000.0     2    1.0   800.000000
# 15255       Toronto  Long Term  Apartment  2600.0     2    1.0  1371.060606
# 18400  Lloydminster  Long Term  Apartment  1568.0     3    1.0   971.000000
#
#         furnishing      smoking  cats  dogs
# 5042   Unfurnished  Non-Smoking     1     1
# 17896  Unfurnished  Non-Smoking     0     0
# 3616   Unfurnished  Non-Smoking     1     1
# 15255  Unfurnished      Unknown     0     0
# 18400  Unfurnished  Non-Smoking     1     1

# %% [markdown]
# ### 3.2 Non-ordinal

# %%
# Check the number of unique values
df[['city', 'lease_term', 'type', 'furnishing', 'smoking']].nunique()
# Out:
# city          269
# lease_term      7
# type           15
# furnishing      3
# smoking         5
# dtype: int64

# %% [markdown]
# We will use Onehot Encoding for all the mentionned features, except city. It would increase the cardinality of the input features way too much. We will use Frequency Encoding, to encode that the cities with the most ads are big cities, which is most likely related to higher prices.

# %%
# Map the city with the frequency
city_frequency_map = df['city'].value_counts()
city_frequency_map
# Out:
# city
# Calgary             4721
# Edmonton            2570
# Toronto             2395
# Montréal            1516
# Ottawa              1084
#                     ...
# Christopher Lake       1
# Priddis                1
# Innisfail              1
# Langdon                1
# Crowsnest Pass         1
# Name: count, Length: 269, dtype: int64

# %%
# Apply frequency encoding
df['city'] = df['city'].map(city_frequency_map)
df.head()
# Out:
#    city lease_term       type   price  beds  baths  sq_feet   furnishing  \
# 0   128  Long Term  Townhouse  2495.0     2    2.5   1403.0  Unfurnished
# 1   128  Long Term  Townhouse  2695.0     3    2.5   1496.0  Unfurnished
# 2   128  Long Term  Townhouse  2295.0     2    2.5   1180.0  Unfurnished
# 3   128  Long Term  Townhouse  2095.0     2    2.5   1403.0  Unfurnished
# 4   128  Long Term  Townhouse  2495.0     2    2.5   1351.0  Unfurnished
#
#        smoking  cats  dogs
# 0  Non-Smoking     1     1
# 1  Non-Smoking     1     1
# 2  Non-Smoking     1     1
# 3  Non-Smoking     1     1
# 4  Non-Smoking     1     1

# %%
# Apply OneHotEncoder for the other features
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_cols = encoder.fit_transform(df[['lease_term', 'type', 'furnishing', 'smoking']])
new_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(['lease_term', 'type', 'furnishing', 'smoking']))
df = df.drop(columns=['lease_term', 'type', 'furnishing', 'smoking'], axis=1).join(new_df)
df.sample(5)
# Out:
#        city   price  beds  baths      sq_feet  cats  dogs  \
# 13855  2395  2725.0     1    1.0   494.000000     1     1
# 9014     57  2350.0     2    1.0   950.000000     1     1
# 10554   118  2995.0     3    2.5  1800.000000     1     1
# 44      128  1737.0     2    1.0   792.000000     1     1
# 17378  1516  1790.0     1    1.0  1371.060606     1     1
#
#        lease_term_6 months  lease_term_Long Term  lease_term_Negotiable  ...  \
# 13855                  0.0                   1.0                    0.0  ...
# 9014                   0.0                   1.0                    0.0  ...
# 10554                  0.0                   1.0                    0.0  ...
# 44                     0.0                   1.0                    0.0  ...
# 17378                  0.0                   1.0                    0.0  ...
#
#        type_Room For Rent  type_Storage  type_Townhouse  type_Vacation Home  \
# 13855                 0.0           0.0             0.0                 0.0
# 9014                  0.0           0.0             0.0                 0.0
# 10554                 0.0           0.0             0.0                 0.0
# 44                    0.0           0.0             0.0                 0.0
# 17378                 0.0           0.0             0.0                 0.0
#
#        furnishing_Negotiable  furnishing_Unfurnished  smoking_Non-Smoking  \
# 13855                    0.0                     1.0                  1.0
# 9014                     0.0                     1.0                  1.0
# 10554                    0.0                     1.0                  1.0
# 44                       0.0                     1.0                  1.0
# 17378                    0.0                     1.0                  0.0
#
#        smoking_Smoke Free Building  smoking_Smoking Allowed  smoking_Unknown
# 13855                          0.0                      0.0              0.0
# 9014                           0.0                      0.0              0.0
# 10554                          0.0                      0.0              0.0
# 44                             0.0                      0.0              0.0
# 17378                          0.0                      0.0              1.0
#
# [5 rows x 33 columns]

# %%
# Make sure there are no more string values
s = df.dtypes
s = s[s != 'object']
assert len(s) == len(df.columns)

# %% [markdown]
# ## 5. Feature Selection

# %%
# Train-test split
X = df.drop('price', axis=1)
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)
X.shape
# Out:
# (19045, 32)

# %%
# Select features using Mutual Info Regresssion, since there might be non-linear relationships between the features.
selector = SelectKBest(score_func=mutual_info_regression, k=10)
X_train_selected = selector.fit_transform(X_train_scaled, y_train)
selected_features = selector.get_feature_names_out(X.columns)
selected_columns = list(selected_features)
selected_columns.append('price')
df = df[selected_columns]
df.sample(5)
# Out:
#        city  beds  baths  sq_feet  cats  dogs  type_Apartment  type_Basement  \
# 8292     97     1    1.0    720.0     1     1             1.0            0.0
# 12833  1084     1    1.0    360.0     0     0             1.0            0.0
# 4308   4721     2    2.0    902.0     1     1             1.0            0.0
# 12996  1084     4    1.0   1449.0     1     1             1.0            0.0
# 1600   4721     3    3.5   1895.0     0     0             0.0            0.0
#
#        type_House  type_Room For Rent   price
# 8292          0.0                 0.0  2205.0
# 12833         0.0                 0.0  2200.0
# 4308          0.0                 0.0  2100.0
# 12996         0.0                 0.0  2725.0
# 1600          0.0                 0.0  3350.0

# %%
# Dump preprocessed data into a pickle file
data = {
    'city_frequency_map': city_frequency_map,
    'df': df,
}

with open('../Data/preprocessed_data.pkl', 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## End
