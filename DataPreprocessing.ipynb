# %% [markdown]
# # Canadian Rental Prices Feature Engineering and Data Preprocessing

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook prepares the data for a regression model that will predict the price of a rental based on multiple factors.
#
# We're going to work with the data that's been explored and cleaned in [this notebook](DataAnalysis.ipynb). The dataset contains rental prices data associated with multiple factors, like the location, type of rental, number of rooms, etc.
#
# The model selection to predict the price will be made in [this notebook](DataModeling.ipynb).

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.feature_selection import mutual_info_regression, SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
# Load the data
df = pd.read_csv('Data/cleaned_data.csv')
df.shape
# Out:
# (18832, 19)

# %%
df.sample(5)
# Out:
#        rentfaster_id      city province                   address   latitude  \
# 2905          124935   Calgary  Alberta      58 Cranleigh Terrace  50.886247
# 6712          569124  Edmonton  Alberta  8918 88 Avenue Northwest  53.523639
# 13773         523076   Toronto  Ontario   2376 Dundas Street West  43.657961
# 1127          547253   Calgary  Alberta               Arbour Lake  51.133625
# 365           361795   Calgary  Alberta          620 10 Avenue SW  51.044004
#
#         longitude  lease_term        type   price  beds  baths  sq_feet  \
# 2905  -113.992509  Negotiable    Basement  1800.0     1    1.0   1300.0
# 6712  -113.464965   Long Term  Main Floor  2600.0     3    1.0   1300.0
# 13773  -79.451842   Long Term   Apartment  3110.0     2    1.0    783.0
# 1127  -114.193320   Long Term       House  3500.0     4    3.0   1322.0
# 365   -114.075438   Long Term   Apartment  2319.0     1    1.0    612.0
#
#                                                     link   furnishing  \
# 2905   /ab/calgary/rentals/basement/1-bedroom/cransto...  Unfurnished
# 6712   /ab/edmonton/rentals/main-floor/3-bedrooms/bon...  Unfurnished
# 13773  /on/toronto/rentals/apartment/1-bedroom/pet-fr...  Unfurnished
# 1127   /ab/calgary/rentals/house/4-bedrooms/arbour-la...  Unfurnished
# 365    /ab/calgary/rentals/apartment/1-bedroom/beltli...  Unfurnished
#
#       availability_date              smoking   cats   dogs postal_code
# 2905            July 01          Non-Smoking   True  False         T3M
# 6712            July 01          Non-Smoking  False  False         T6C
# 13773         Immediate  Smoke Free Building   True   True         M6P
# 1127          Immediate          Non-Smoking   True   True         T3G
# 365           August 07          Non-Smoking   True   True         T2R

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Simplify model by removing some columns

# %% [markdown]
# **rentfaster_id**: An ID column is not correlated in any way with the price.
#
# **province, city, address, latitude & longitude**: The postal code includes the province, city and neighbourhood.
#
# **link**: The link has no correlation with the price.
#
# **availability_date**: I don't think the availability date has anything to do with the price.

# %%
df = df.drop(columns=['rentfaster_id', 'province', 'city', 'address', 'latitude', 'longitude', 'link', 'availability_date'], axis=1)
df.sample(5)
# Out:
#       lease_term       type   price  beds  baths  sq_feet   furnishing  \
# 13785  Long Term  Apartment  3120.0     2    1.0    783.0  Unfurnished
# 13219  Long Term  Apartment  1585.0     1    1.0    574.0  Unfurnished
# 16638  Long Term  Apartment  2875.0     2    1.0    585.0  Unfurnished
# 3510   Long Term  Apartment  2085.0     2    2.0    900.0  Unfurnished
# 14690  Long Term  Apartment  2001.0     0    1.0      0.0  Unfurnished
#
#                    smoking  cats  dogs postal_code
# 13785  Smoke Free Building  True  True         M6P
# 13219          Non-Smoking  True  True         N5R
# 16638          Non-Smoking  True  True         H3A
# 3510           Non-Smoking  True  True         T2Y
# 14690          Non-Smoking  True  True         M6P

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Encode categorical columns

# %% [markdown]
# ### 2.1 Boolean

# %%
# Create dummy variables
df = df.assign(
    dogs=np.where(df['dogs'] == True, 1, 0),
    cats=np.where(df['cats'] == True, 1, 0),
)
df.sample(5)
# Out:
#       lease_term       type   price  beds  baths  sq_feet   furnishing  \
# 15581  Long Term  Apartment  2150.0     1    1.0    500.0  Unfurnished
# 16390  Long Term  Apartment  1770.0     1    1.0    829.0  Unfurnished
# 14145  Long Term  Apartment  3934.0     3    2.0    943.0  Unfurnished
# 9350   Long Term  Apartment  1805.0     2    1.0    845.0  Unfurnished
# 8217   Long Term  Townhouse  3368.0     3    2.5   1585.0  Unfurnished
#
#            smoking  cats  dogs postal_code
# 15581  Non-Smoking     1     1         M9B
# 16390  Non-Smoking     1     1         H7P
# 14145  Non-Smoking     1     1         M6G
# 9350   Non-Smoking     1     1         V4T
# 8217       Unknown     1     1         V1W

# %% [markdown]
# ### 2.2 Non-ordinal

# %%
# Check the number of unique values
df[['postal_code', 'lease_term', 'type', 'furnishing', 'smoking']].nunique()
# Out:
# postal_code    698
# lease_term       7
# type            15
# furnishing       3
# smoking          5
# dtype: int64

# %% [markdown]
# We will use Onehot Encoding for all the mentionned features, except postal code. It would increase the cardinality of the input features way too much. We will use Frequency Encoding instead.

# %%
# Map the city with the frequency
pc_frequency_map = df['postal_code'].value_counts()
pc_frequency_map
# Out:
# postal_code
# K1N    369
# T2R    329
# T5K    290
# T3M    289
# T2T    277
#       ...
# L1T      2
# K7N      2
# L9G      2
# L2H      2
# P1A      2
# Name: count, Length: 698, dtype: int64

# %%
# Apply frequency encoding
df['postal_code'] = df['postal_code'].map(pc_frequency_map)
df.head()
# Out:
#   lease_term       type   price  beds  baths  sq_feet   furnishing  \
# 0  Long Term  Townhouse  2495.0     2    2.5   1403.0  Unfurnished
# 1  Long Term  Townhouse  2695.0     3    2.5   1496.0  Unfurnished
# 2  Long Term  Townhouse  2295.0     2    2.5   1180.0  Unfurnished
# 3  Long Term  Townhouse  2095.0     2    2.5   1403.0  Unfurnished
# 4  Long Term  Townhouse  2495.0     2    2.5   1351.0  Unfurnished
#
#        smoking  cats  dogs  postal_code
# 0  Non-Smoking     1     1          156
# 1  Non-Smoking     1     1          156
# 2  Non-Smoking     1     1          156
# 3  Non-Smoking     1     1          156
# 4  Non-Smoking     1     1          156

# %%
# Apply OneHotEncoder for the other features
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_cols = encoder.fit_transform(df[['lease_term', 'type', 'furnishing', 'smoking']])
new_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(['lease_term', 'type', 'furnishing', 'smoking']))
df = df.drop(columns=['lease_term', 'type', 'furnishing', 'smoking'], axis=1).join(new_df)
df.sample(5)
# Out:
#          price  beds  baths  sq_feet  cats  dogs  postal_code  \
# 10994  1560.00     0    1.0    406.0     1     1          145
# 18454  1559.00     2    1.0    877.0     1     1           36
# 11794  2443.11     1    1.0    660.0     0     0           60
# 2544   2300.00     2    1.0    870.0     0     0          329
# 11374  1810.00     2    1.0    807.0     1     1           16
#
#        lease_term_6 months  lease_term_Long Term  lease_term_Negotiable  ...  \
# 10994                  0.0                   1.0                    0.0  ...
# 18454                  0.0                   1.0                    0.0  ...
# 11794                  0.0                   1.0                    0.0  ...
# 2544                   0.0                   1.0                    0.0  ...
# 11374                  0.0                   1.0                    0.0  ...
#
#        type_Room For Rent  type_Storage  type_Townhouse  type_Vacation Home  \
# 10994                 0.0           0.0             0.0                 0.0
# 18454                 0.0           0.0             1.0                 0.0
# 11794                 0.0           0.0             0.0                 0.0
# 2544                  0.0           0.0             0.0                 0.0
# 11374                 0.0           0.0             0.0                 0.0
#
#        furnishing_Negotiable  furnishing_Unfurnished  smoking_Non-Smoking  \
# 10994                    0.0                     1.0                  1.0
# 18454                    0.0                     1.0                  1.0
# 11794                    0.0                     1.0                  1.0
# 2544                     0.0                     1.0                  1.0
# 11374                    0.0                     1.0                  1.0
#
#        smoking_Smoke Free Building  smoking_Smoking Allowed  smoking_Unknown
# 10994                          0.0                      0.0              0.0
# 18454                          0.0                      0.0              0.0
# 11794                          0.0                      0.0              0.0
# 2544                           0.0                      0.0              0.0
# 11374                          0.0                      0.0              0.0
#
# [5 rows x 33 columns]

# %%
# Make sure there are no more string values
s = df.dtypes
s = s[s != 'object']
assert len(s) == len(df.columns)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Feature Selection

# %%
# Train-test split
X = df.drop('price', axis=1)
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
X.shape
# Out:
# (18832, 32)

# %%
# Select features using Mutual Info Regresssion, since there might be non-linear relationships between the features.
selector = SelectKBest(score_func=mutual_info_regression, k=10)
X_train_selected = selector.fit_transform(X_train, y_train)
selected_features = selector.get_feature_names_out(X.columns)
selected_columns = list(selected_features)
selected_columns.append('price')
df = df[selected_columns]
df.sample(5)
# Out:
#        beds  baths      sq_feet  cats  dogs  postal_code  type_Apartment  \
# 15561     1    1.0  1371.060606     1     1           18             1.0
# 2526      2    1.0  1371.060606     0     0          152             0.0
# 16224     1    1.0     0.000000     1     1            4             1.0
# 10877     1    1.0   550.000000     1     1            5             1.0
# 9661      3    1.5     0.000000     0     0           69             0.0
#
#        type_Basement  type_House  type_Room For Rent   price
# 15561            0.0         0.0                 0.0  2000.0
# 2526             0.0         0.0                 0.0  1775.0
# 16224            0.0         0.0                 0.0  1254.0
# 10877            0.0         0.0                 0.0  1840.0
# 9661             0.0         0.0                 0.0  1700.0

# %%
# Dump preprocessed data into a pickle file
data = {
    'pc_frequency_map': pc_frequency_map,
    'df': df,
}

with open('Data/preprocessed_data.pkl', 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## End
